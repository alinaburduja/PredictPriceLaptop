# %%
import pandas as pd
import numpy as np
import re
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
laptops = pd.read_csv("drive/MyDrive/Learn/laptops.csv", encoding='latin-1')

# %%
laptops.head()
# Out:
#   Company      Product  Inches  ...   Ram  Weight Price_euros
# 0   Apple  MacBook Pro    13.3  ...   8GB  1.37kg     1339.69
# 1   Apple  Macbook Air    13.3  ...   8GB  1.34kg      898.94
# 2      HP       250 G6    15.6  ...   8GB  1.86kg      575.00
# 3   Apple  MacBook Pro    15.4  ...  16GB  1.83kg     2537.45
# 4   Apple  MacBook Pro    13.3  ...   8GB  1.37kg     1803.60
#
# [5 rows x 7 columns]

# %%
laptops.shape
# Out:
# (1303, 7)

# %%
laptops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1303 non-null   object
#  1   Product      1303 non-null   object
#  2   Inches       1303 non-null   float64
#  3   Cpu          1303 non-null   object
#  4   Ram          1303 non-null   object
#  5   Weight       1303 non-null   object
#  6   Price_euros  1303 non-null   float64
# dtypes: float64(2), object(5)
# memory usage: 71.4+ KB

# %%
laptops['Price_euros'].unique()
# Out:
# array([1339.69,  898.94,  575.  , 2537.45, 1803.6 ,  400.  , 2139.97,
#        1158.7 , 1495.  ,  770.  ,  393.9 ,  344.99, 2439.97,  498.9 ,
#        1262.4 , 1518.55,  745.  , 2858.  ,  499.  ,  979.  ,  191.9 ,
#         999.  ,  258.  ,  819.  ,  659.  ,  418.64, 1099.  ,  800.  ,
#        1298.  ,  896.  ,  244.99,  199.  ,  439.  , 1869.  ,  998.  ,
#         249.  ,  367.  ,  488.69,  879.  ,  389.  , 1499.  ,  522.99,
#         682.  , 1419.  ,  369.  , 1299.  ,  639.  ,  466.  ,  319.  ,
#         841.  ,  398.49, 1103.  ,  384.  ,  767.8 ,  586.19, 2449.  ,
#         415.  ,  599.  ,  941.  ,  690.  , 1983.  ,  438.69,  229.  ,
#         549.  ,  949.  , 1089.  ,  955.  ,  870.  , 1095.  ,  519.  ,
#         855.  ,  530.  ,  977.  , 1096.16, 1510.  ,  860.  ,  399.  ,
#         395.  , 1349.  ,  699.  ,  598.99, 1449.  , 1649.  ,  689.  ,
#        1197.  , 1195.  , 1049.  ,  847.  ,  599.9 ,  485.  ,  577.  ,
# ...

# %%
laptops['Weight'].unique()
# Out:
# array(['1.37kg', '1.34kg', '1.86kg', '1.83kg', '2.1kg', '2.04kg', '1.3kg',
#        '1.6kg', '2.2kg', '0.92kg', '1.22kg', '0.98kg', '2.5kg', '1.62kg',
#        '1.91kg', '2.3kg', '1.35kg', '1.88kg', '1.89kg', '1.65kg',
#        '2.71kg', '1.2kg', '1.44kg', '2.8kg', '2kg', '2.65kg', '2.77kg',
#        '3.2kg', '0.69kg', '1.49kg', '2.4kg', '2.13kg', '2.43kg', '1.7kg',
#        '1.4kg', '1.8kg', '1.9kg', '3kg', '1.252kg', '2.7kg', '2.02kg',
#        '1.63kg', '1.96kg', '1.21kg', '2.45kg', '1.25kg', '1.5kg',
#        '2.62kg', '1.38kg', '1.58kg', '1.85kg', '1.23kg', '1.26kg',
#        '2.16kg', '2.36kg', '2.05kg', '1.32kg', '1.75kg', '0.97kg',
#        '2.9kg', '2.56kg', '1.48kg', '1.74kg', '1.1kg', '1.56kg', '2.03kg',
#        '1.05kg', '4.4kg', '1.90kg', '1.29kg', '2.0kg', '1.95kg', '2.06kg',
#        '1.12kg', '1.42kg', '3.49kg', '3.35kg', '2.23kg', '4.42kg',
#        '2.69kg', '2.37kg', '4.7kg', '3.6kg', '2.08kg', '4.3kg', '1.68kg',
# ...

# %%
laptops['Ram'].unique()
# Out:
# array(['8GB', '16GB', '4GB', '2GB', '12GB', '6GB', '32GB', '24GB', '64GB'],
#       dtype=object)

# %%
laptops['Cpu'].unique()
# Out:
# array(['Intel Core i5 2.3GHz', 'Intel Core i5 1.8GHz',
#        'Intel Core i5 7200U 2.5GHz', 'Intel Core i7 2.7GHz',
#        'Intel Core i5 3.1GHz', 'AMD A9-Series 9420 3GHz',
#        'Intel Core i7 2.2GHz', 'Intel Core i7 8550U 1.8GHz',
#        'Intel Core i5 8250U 1.6GHz', 'Intel Core i3 6006U 2GHz',
#        'Intel Core i7 2.8GHz', 'Intel Core M m3 1.2GHz',
#        'Intel Core i7 7500U 2.7GHz', 'Intel Core i7 2.9GHz',
#        'Intel Core i3 7100U 2.4GHz', 'Intel Atom x5-Z8350 1.44GHz',
#        'Intel Core i5 7300HQ 2.5GHz', 'AMD E-Series E2-9000e 1.5GHz',
#        'Intel Core i5 1.6GHz', 'Intel Core i7 8650U 1.9GHz',
#        'Intel Atom x5-Z8300 1.44GHz', 'AMD E-Series E2-6110 1.5GHz',
#        'AMD A6-Series 9220 2.5GHz',
#        'Intel Celeron Dual Core N3350 1.1GHz',
#        'Intel Core i3 7130U 2.7GHz', 'Intel Core i7 7700HQ 2.8GHz',
#        'Intel Core i5 2.0GHz', 'AMD Ryzen 1700 3GHz',
#        'Intel Pentium Quad Core N4200 1.1GHz',
# ...

# %%
laptops['Inches'].unique()
# Out:
# array([13.3, 15.6, 15.4, 14. , 12. , 11.6, 17.3, 10.1, 13.5, 12.5, 13. ,
#        18.4, 13.9, 12.3, 17. , 15. , 14.1, 11.3])

# %%
laptops['Product'].unique()
# Out:
# array(['MacBook Pro', 'Macbook Air', '250 G6', 'Aspire 3',
#        'ZenBook UX430UN', 'Swift 3', 'Inspiron 3567', 'MacBook 12"',
#        'IdeaPad 320-15IKB', 'XPS 13', 'Vivobook E200HA',
#        'Legion Y520-15IKBN', '255 G6', 'Inspiron 5379',
#        '15-BS101nv (i7-8550U/8GB/256GB/FHD/W10)', 'MacBook Air',
#        'Inspiron 5570', 'Latitude 5590', 'ProBook 470', 'LapBook 15.6"',
#        'E402WA-GA010T (E2-6110/2GB/32GB/W10)',
#        '17-ak001nv (A6-9220/4GB/500GB/Radeon', 'IdeaPad 120S-14IAP',
#        'Inspiron 5770', 'ProBook 450',
#        'X540UA-DM186 (i3-6006U/4GB/1TB/FHD/Linux)', 'Inspiron 7577',
#        'X542UQ-GO005 (i5-7200U/8GB/1TB/GeForce', 'Aspire A515-51G',
#        'Inspiron 7773', 'IdeaPad 320-15ISK', 'Rog Strix',
#        'X751NV-TY001T (N4200/4GB/1TB/GeForce', 'Yoga Book', 'ProBook 430',
#        'Inspiron 3576', '15-bs002nv (i3-6006U/4GB/128GB/FHD/W10)',
#        'VivoBook Max', 'GS73VR 7RG',
# ...

# %%
laptops['Company'].unique()
# Out:
# array(['Apple', 'HP', 'Acer', 'Asus', 'Dell', 'Lenovo', 'Chuwi', 'MSI',
#        'Microsoft', 'Toshiba', 'Huawei', 'Xiaomi', 'Vero', 'Razer',
#        'Mediacom', 'Samsung', 'Google', 'Fujitsu', 'LG'], dtype=object)

# %% [markdown]
# ### **Cleaning**

# %%
copy = laptops.copy()

# %%
def removeAfterElement():
  processedElements = []
  for element in laptops['Product']:
    processedElements.append(element.split('(', 1)[0])

  laptops['Product'] = processedElements

# %%
removeAfterElement()

# %%
laptops.describe()
# Out:
#             Inches  Price_euros
# count  1303.000000  1303.000000
# mean     15.017191  1123.686992
# std       1.426304   699.009043
# min      10.100000   174.000000
# 25%      14.000000   599.000000
# 50%      15.600000   977.000000
# 75%      15.600000  1487.880000
# max      18.400000  6099.000000

# %%
laptops.to_csv('drive/MyDrive/Learn/Cleaned Laptops.csv')

# %% [markdown]
# ### **Model**

# %%
X = laptops.drop(columns = 'Price_euros')
y = laptops['Price_euros']

# %%
X
# Out:
#      Company             Product  ...   Ram  Weight
# 0      Apple         MacBook Pro  ...   8GB  1.37kg
# 1      Apple         Macbook Air  ...   8GB  1.34kg
# 2         HP              250 G6  ...   8GB  1.86kg
# 3      Apple         MacBook Pro  ...  16GB  1.83kg
# 4      Apple         MacBook Pro  ...   8GB  1.37kg
# ...      ...                 ...  ...   ...     ...
# 1298  Lenovo      Yoga 500-14ISK  ...   4GB   1.8kg
# 1299  Lenovo      Yoga 900-13ISK  ...  16GB   1.3kg
# 1300  Lenovo  IdeaPad 100S-14IBR  ...   2GB   1.5kg
# 1301      HP         15-AC110nv   ...   6GB  2.19kg
# 1302    Asus      X553SA-XX031T   ...   4GB   2.2kg
#
# [1303 rows x 6 columns]

# %%
y
# Out:
# 0       1339.69
# 1        898.94
# 2        575.00
# 3       2537.45
# 4       1803.60
#          ...
# 1298     638.00
# 1299    1499.00
# 1300     229.00
# 1301     764.00
# 1302     369.00
# Name: Price_euros, Length: 1303, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
ohe = OneHotEncoder()
ohe.fit(X[['Company', 'Product', 'Cpu', 'Ram','Weight']])
# Out:
# OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='error', sparse=True)

# %%
ohe.categories_
# Out:
# [array(['Acer', 'Apple', 'Asus', 'Chuwi', 'Dell', 'Fujitsu', 'Google',
#         'HP', 'Huawei', 'LG', 'Lenovo', 'MSI', 'Mediacom', 'Microsoft',
#         'Razer', 'Samsung', 'Toshiba', 'Vero', 'Xiaomi'], dtype=object),
#  array(['110-15ACL ', '14-am079na ', '15-AC110nv ', '15-AY023na ',
#         '15-BA015wm ', '15-BS026nv ', '15-BS028nv ', '15-BS078nr ',
#         '15-BS101nv ', '15-BS103nv ', '15-BW004nv ', '15-BW037na ',
#         '15-BW091ND ', '15-BW094nd ', '15-ay047nv ', '15-ba043na ',
#         '15-bs002nv ', '15-bs005nv ', '15-bs011nv ', '15-bs012nv ',
#         '15-bs015dx ', '15-bs017nv ', '15-bs018nq ', '15-bs023nv ',
#         '15-bs024nv ', '15-bs025nv ', '15-bs053od ', '15-bs078cl ',
#         '15-bs190od ', '15-bw000nv ', '15-bw002nv ', '15-bw003nv ',
#         '15-bw007nv ', '15-bw009nv ', '15-bw011nv ', '15-cb003na ',
#         '15-cd005nv ', '15-ra044nv ', '15-rb013nv ', '17-AK091ND ',
#         '17-BS037cl ', '17-BS092ND ', '17-X047na ', '17-Y002nv ',
# ...

# %%
column_trans = make_column_transformer((OneHotEncoder(categories=ohe.categories_), ['Company', 'Product', 'Cpu', 'Ram','Weight']),remainder = 'passthrough')

# %%
lr = LinearRegression()

# %%
pipe = make_pipeline(column_trans, lr)

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('columntransformer',
#                  ColumnTransformer(n_jobs=None, remainder='passthrough',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Acer', 'Apple', 'Asus', 'Chuwi', 'Dell', 'Fujitsu', 'Google',
#        'HP', 'Huawei', 'LG', 'Lenovo', 'MSI', 'Mediacom', 'Microsoft',
#        'Razer', 'Samsung', 'Toshi...
#        '4.0kg', '4.14kg', '4.2kg', '4.33kg', '4.36kg', '4.3kg', '4.42kg',
#        '4.4kg', '4.5kg', '4.6kg', '4.7kg', '4kg'], dtype=object)],
#                                                                 drop=None,
#                                                                 dtype=<class 'numpy.float64'>,
#                                                                 handle_unknown='error',
# ...

# %%
y_pred = pipe.predict(X_test)

# %%
y_pred
# Out:
# array([1157.78617967, 1130.32998507, 1199.00003466, 1299.80965024,
#        1606.15659135,  692.76592141, 1655.39729138, 1317.63903675,
#         561.41079553,  959.00026155, 1039.68631903, 1242.13415056,
#        2434.30005992,  981.67559501,  784.55617523, 1468.36998367,
#         831.59823685, 2141.46582475,  802.81764595, 1071.77525732,
#         796.7377691 ,  787.27010209,  350.46142056,  123.69967689,
#         735.50816234, 1382.9239529 , 1474.51287967,  551.95646015,
#        1044.87691797,  677.71650476, 1672.58634113, 2086.07050467,
#        1133.60461793, 1281.89702029,  400.74547358,  579.34757873,
#        2054.40214445,  831.59823685,  638.00013921,  745.09703195,
#        1867.56109645,  882.17498001, 2362.97953558, 1598.06629827,
#         966.73739007,  845.14920498,  633.77694041, 2035.52228983,
#        1158.48515166,  340.99530471, 1432.03528759,  455.80346975,
#         733.89653668, 1770.41986739,  876.26814998, 1919.85878797,
# ...

# %%
r2_score(y_test, y_pred)
# Out:
# 0.6689380658909895

# %%
scores = []
for i in range(1000):
  X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2, random_state = i)
  lr = LinearRegression()
  pipe = make_pipeline(column_trans, lr)
  pipe.fit(X_train, y_train)
  y_pred = pipe.predict(X_test)
  scores.append(r2_score(y_test, y_pred))

# %%
np.argmax(scores)
# Out:
# 395

# %%
scores[np.argmax(scores)]
# Out:
# 0.8296078196630455

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2, random_state = np.argmax(scores))
lr = LinearRegression()
pipe = make_pipeline(column_trans, lr)
pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)
r2_score(y_test, y_pred)
# Out:
# 0.8296078196630455

# %%
import pickle

# %%
pickle.dump(pipe, open('LinearRegressionModel.pkl','wb'))

# %%
pipe.predict(pd.DataFrame([['Lenovo','IdeaPad 320-15IKB','15.6','Intel Core i3 7100U 2.4GHz','8GB','2.2kg']], columns=['Company','Product','Inches','Cpu','Ram','Weight']))
# Out:
# array([575.87903587])
